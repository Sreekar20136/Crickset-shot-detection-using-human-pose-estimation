# %% [markdown]
# ## Preparation

# %%
# !pip install -q opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive/',force_remount = False)
# Out:
# Mounted at /content/drive/

# %%
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')


def detect(input_tensor, inference_count=3):

  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)


  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23708, done.
# remote: Counting objects: 100% (672/672), done.
# remote: Compressing objects: 100% (412/412), done.
# remote: Total 23708 (delta 218), reused 610 (delta 172), pack-reused 23036
# Receiving objects: 100% (23708/23708), 44.18 MiB | 31.03 MiB/s, done.
# Resolving deltas: 100% (12866/12866), done.

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):




  image_np = utils.visualize(image, [person])


  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):

    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []


    self._csvs_out_folder_per_class = tempfile.mkdtemp()


    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):

    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(np.str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %%
is_skip_step_1 = False

# %%
use_custom_dataset = True

dataset_is_split = False

# %%
import os
import random
import shutil

def split_into_train_test(images_origin, images_dest, test_split):

  _, dirs, _ = next(os.walk(images_origin))

  TRAIN_DIR = os.path.join(images_dest, 'train')
  TEST_DIR = os.path.join(images_dest, 'test')
  os.makedirs(TRAIN_DIR, exist_ok=True)
  os.makedirs(TEST_DIR, exist_ok=True)

  for dir in dirs:
    # Get all filenames for this dir, filtered by filetype
    filenames = os.listdir(os.path.join(images_origin, dir))
    filenames = [os.path.join(images_origin, dir, f) for f in filenames if (
        f.endswith('.png') or f.endswith('.jpg') or f.endswith('.jpeg') or f.endswith('.bmp'))]
    # Shuffle the files, deterministically
    filenames.sort()
    random.seed(42)
    random.shuffle(filenames)
    # Divide them into train/test dirs
    os.makedirs(os.path.join(TEST_DIR, dir), exist_ok=True)
    os.makedirs(os.path.join(TRAIN_DIR, dir), exist_ok=True)
    test_count = int(len(filenames) * test_split)
    for i, file in enumerate(filenames):
      if i < test_count:
        destination = os.path.join(TEST_DIR, dir, os.path.split(file)[1])
      else:
        destination = os.path.join(TRAIN_DIR, dir, os.path.split(file)[1])
      shutil.copyfile(file, destination)
    print(f'Moved {test_count} of {len(filenames)} from class "{dir}" into test.')
  print(f'Your split dataset is in "{images_dest}"')

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/legglance flick.zip', 'r') as zip_ref:
    zip_ref.extractall('final/')

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/Sweep.zip', 'r') as zip_ref:
    zip_ref.extractall('final/')

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/Pull shot.zip', 'r') as zip_ref:
    zip_ref.extractall('final/')

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/Drive.zip', 'r') as zip_ref:
    zip_ref.extractall('final/')

# %%
if use_custom_dataset:


  dataset_in = '/content/final'

  # You can leave the rest alone:
  if not os.path.isdir(dataset_in):
    raise Exception("dataset_in is not a valid directory")
  if dataset_is_split:
    IMAGES_ROOT = dataset_in
  else:
    dataset_out = 'split_' + dataset_in
    split_into_train_test(dataset_in, dataset_out, test_split=0.2)
    IMAGES_ROOT = dataset_out
# Out:
# Moved 176 of 884 from class "Drive" into test.
# Moved 176 of 880 from class "Sweep" into test.
# Moved 176 of 884 from class "legglance flick" into test.
# Moved 175 of 877 from class "Pull shot" into test.
# Your split dataset is in "split_/content/final"

# %% [markdown]
# ### Preprocess the `TRAIN` dataset

# %%
  images_in_train_folder = os.path.join(IMAGES_ROOT, 'train')
  images_out_train_folder = 'poses_images_out_train'
  csvs_out_train_path = 'train_data.csv'

  preprocessor = MoveNetPreprocessor(
      images_in_folder=images_in_train_folder,
      images_out_folder=images_out_train_folder,
      csvs_out_path=csvs_out_train_path,
  )

  preprocessor.process(per_pose_class_limit=None)
# Out:
# Preprocessing Drive
#   0%|          | 0/708 [00:00<?, ?it/s]<ipython-input-6-c4e95dcbb297>:98: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coordinates = pose_landmarks.flatten().astype(np.str).tolist()
r/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 176/176 [10:11<00:00,  3.48s/it]
# Preprocessing Pull shot
# 100%|██████████| 175/175 [10:11<00:00,  3.49s/it]
# Preprocessing Sweep
# 100%|██████████| 176/176 [10:13<00:00,  3.49s/it]
# Preprocessing legglance flick
# 100%|██████████| 176/176 [10:18<00:00,  3.52s/it]
# Skipped split_/content/final/test/Drive/drives124.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives125.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives129.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives131.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives144.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives154.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives256.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives278.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives279.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives28.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives280.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives281.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives299.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives303.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives323.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives325.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives340.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives349.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives359.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives377.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives380.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives392.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives396.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives400.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives418.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives442.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives445.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives446.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives452.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives453.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives456.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives493.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives529.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives541.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives543.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives551.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives564.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives57.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives571.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives572.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives579.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives59.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives595.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives60.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives602.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives607.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives632.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives639.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives64.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives640.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives644.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives646.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives655.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives667.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives694.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives705.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives71.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives710.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives712.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives734.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives743.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives747.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives753.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives754.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives763.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives775.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives789.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives80.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives81.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives83.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives830.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives844.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives859.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives860.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives869.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Drive/drives874.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot207.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot213.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot22.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot239.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot25.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot253.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot289.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot344.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot375.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot391.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot417.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot433.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot44.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot445.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot454.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot459.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot469.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot479.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot481.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot485.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot496.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot505.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot531.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot533.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot544.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot556.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot565.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot568.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot59.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot590.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot592.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot593.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot611.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot651.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot661.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot662.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot68.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot685.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot688.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot692.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot694.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot7.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot704.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot710.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot739.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot760.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot765.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot768.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot779.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot782.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot791.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot796.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot800.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot805.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot81.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot814.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot815.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot817.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot82.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot820.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot833.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot855.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot869.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot877.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot89.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot904.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot916.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot922.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot934.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot941.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot949.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot974.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot978.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot983.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot986.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Pull shot/pullshot995.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep110.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep127.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep143.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep147.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep215.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep234.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep236.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep265.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep273.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep278.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep279.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep28.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep281.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep299.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep303.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep305.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep311.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep314.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep321.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep323.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep340.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep359.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep363.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep377.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep38.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep437.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep452.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep465.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep476.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep480.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep519.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep524.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep526.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep527.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep540.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep541.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep544.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep555.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep60.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep602.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep604.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep613.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep617.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep620.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep636.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep639.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep646.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep671.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep68.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep694.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep708.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep71.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep731.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep734.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep741.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep760.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep77.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep786.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep812.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep827.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep83.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep84.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep85.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep861.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep870.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep89.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/Sweep/sweep95.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance108.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance194.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance199.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance254.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance256.jpeg. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance265.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance303.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance308.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance33.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance340.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance360.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance381.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance396.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance397.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance4.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance401.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance418.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance428.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance442.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance463.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance498.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance503.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance513.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance514.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance543.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance551.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance561.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance564.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance571.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance580.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance583.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance595.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance607.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance645.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance655.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance734.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance740.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance743.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance747.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance753.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance754.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance760.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance763.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance80.jpeg. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance809.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance826.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance839.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance859.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance865.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance874.png. No pose was confidentlly detected.
# Skipped split_/content/final/test/legglance flick/legglance95.png. No pose was confidentlly detected.

# %%
def load_pose_landmarks(csv_path):

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

# Split training data (X, y) into (X_train, y_train) and (X_val, y_val)
X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.15)

# %%
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(51))
embedding = landmarks_to_embedding(inputs)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model=keras.Model(inputs, outputs)
model.summary()



#model = keras.Sequential([

    #keras.Input(shape=(784)),
    #layers.Dense(256, activation='softmax'),

    # dense layer 2
    #layers.Dense(128, activation='softmax'),

      # output layer
    #layers.Dense(10, activation='softmax'),
#])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 51)]                 0         []
#
#  reshape (Reshape)           (None, 17, 3)                0         ['input_1[0][0]']
#
#  tf.__operators__.getitem (  (None, 17, 2)                0         ['reshape[0][0]']
#  SlicingOpLambda)
#
#  tf.compat.v1.gather (TFOpL  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  ambda)                                                             0]']
#
#  tf.compat.v1.gather_1 (TFO  (None, 2)                    0         ['tf.__operators__.getitem[0][
#  pLambda)                                                           0]']
#
#  tf.math.multiply (TFOpLamb  (None, 2)                    0         ['tf.compat.v1.gather[0][0]']
#  da)
#
#  tf.math.multiply_1 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_1[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add (TFOp  (None, 2)                    0         ['tf.math.multiply[0][0]',
#  Lambda)                                                             'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLam  ()                           0         ['tf.__operators__.getitem[0][
#  bda)                                                               0]']
#
#  tf.expand_dims (TFOpLambda  (None, 1, 2)                 0         ['tf.__operators__.add[0][0]']
#  )
#
#  tf.compat.v1.floor_div (TF  ()                           0         ['tf.compat.v1.size[0][0]']
#  OpLambda)
#
#  tf.broadcast_to (TFOpLambd  (None, 17, 2)                0         ['tf.expand_dims[0][0]',
#  a)                                                                  'tf.compat.v1.floor_div[0][0]
#                                                                     ']
#
#  tf.math.subtract (TFOpLamb  (None, 17, 2)                0         ['tf.__operators__.getitem[0][
#  da)                                                                0]',
#                                                                      'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_7 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.math.multiply_6 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_6[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_7 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_7[0][0]'
#  mbda)                                                              ]
#
#  tf.__operators__.add_3 (TF  (None, 2)                    0         ['tf.math.multiply_6[0][0]',
#  OpLambda)                                                           'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpL  ()                           0         ['tf.math.subtract[0][0]']
#  ambda)
#
#  tf.compat.v1.gather_4 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_5 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_2 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.compat.v1.gather_3 (TFO  (None, 2)                    0         ['tf.math.subtract[0][0]']
#  pLambda)
#
#  tf.expand_dims_1 (TFOpLamb  (None, 1, 2)                 0         ['tf.__operators__.add_3[0][0]
#  da)                                                                ']
#
#  tf.compat.v1.floor_div_1 (  ()                           0         ['tf.compat.v1.size_1[0][0]']
#  TFOpLambda)
#
#  tf.math.multiply_4 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_4[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_5 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_5[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_2 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_2[0][0]'
#  mbda)                                                              ]
#
#  tf.math.multiply_3 (TFOpLa  (None, 2)                    0         ['tf.compat.v1.gather_3[0][0]'
#  mbda)                                                              ]
#
#  tf.broadcast_to_1 (TFOpLam  (None, 17, 2)                0         ['tf.expand_dims_1[0][0]',
#  bda)                                                                'tf.compat.v1.floor_div_1[0][
#                                                                     0]']
#
#  tf.__operators__.add_2 (TF  (None, 2)                    0         ['tf.math.multiply_4[0][0]',
#  OpLambda)                                                           'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 2)                    0         ['tf.math.multiply_2[0][0]',
#  OpLambda)                                                           'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLa  (None, 17, 2)                0         ['tf.math.subtract[0][0]',
#  mbda)                                                               'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLa  (None, 2)                    0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  tf.compat.v1.gather_8 (TFO  (17, 2)                      0         ['tf.math.subtract_2[0][0]']
#  pLambda)
#
#  tf.compat.v1.norm (TFOpLam  ()                           0         ['tf.math.subtract_1[0][0]']
#  bda)
#
#  tf.compat.v1.norm_1 (TFOpL  (2,)                         0         ['tf.compat.v1.gather_8[0][0]'
#  ambda)                                                             ]
#
#  tf.math.multiply_8 (TFOpLa  ()                           0         ['tf.compat.v1.norm[0][0]']
#  mbda)
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.compat.v1.norm_1[0][0]']
#  mbda)
#
#  tf.math.maximum (TFOpLambd  ()                           0         ['tf.math.multiply_8[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpL
200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2798 - accuracy: 0.9045 - val_loss: 0.2010 - val_accuracy: 0.9338
# Epoch 173/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2763 - accuracy: 0.9116 - val_loss: 0.1962 - val_accuracy: 0.9449
# Epoch 174/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2603 - accuracy: 0.9058 - val_loss: 0.1937 - val_accuracy: 0.9375
# Epoch 175/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9168 - val_loss: 0.1939 - val_accuracy: 0.9375
# Epoch 176/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2714 - accuracy: 0.9090 - val_loss: 0.1936 - val_accuracy: 0.9338
# Epoch 177/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2581 - accuracy: 0.9045 - val_loss: 0.1933 - val_accuracy: 0.9265
# Epoch 178/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2749 - accuracy: 0.9058 - val_loss: 0.1930 - val_accuracy: 0.9375
# Epoch 179/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2673 - accuracy: 0.9181 - val_loss: 0.1878 - val_accuracy: 0.9338
# Epoch 180/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.9038 - val_loss: 0.1962 - val_accuracy: 0.9522
# Epoch 181/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2514 - accuracy: 0.9142 - val_loss: 0.1843 - val_accuracy: 0.9375
# Epoch 182/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 0.9097 - val_loss: 0.1820 - val_accuracy: 0.9338
# Epoch 183/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2588 - accuracy: 0.9129 - val_loss: 0.1792 - val_accuracy: 0.9522
# Epoch 184/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2803 - accuracy: 0.9038 - val_loss: 0.1819 - val_accuracy: 0.9485
# Epoch 185/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2584 - accuracy: 0.9064 - val_loss: 0.1864 - val_accuracy: 0.9412
# Epoch 186/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.9116 - val_loss: 0.1808 - val_accuracy: 0.9412
# Epoch 187/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.8986 - val_loss: 0.1818 - val_accuracy: 0.9338
# Epoch 188/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2616 - accuracy: 0.9103 - val_loss: 0.1861 - val_accuracy: 0.9449
# Epoch 189/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2396 - accuracy: 0.9123 - val_loss: 0.1833 - val_accuracy: 0.9375
# Epoch 190/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.9123 - val_loss: 0.1752 - val_accuracy: 0.9485
# Epoch 191/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2514 - accuracy: 0.9181 - val_loss: 0.1734 - val_accuracy: 0.9449
# Epoch 192/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2651 - accuracy: 0.9045 - val_loss: 0.1810 - val_accuracy: 0.9522
# Epoch 193/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2560 - accuracy: 0.9077 - val_loss: 0.1760 - val_accuracy: 0.9522
# Epoch 194/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2505 - accuracy: 0.9162 - val_loss: 0.1792 - val_accuracy: 0.9449
# Epoch 195/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2488 - accuracy: 0.9097 - val_loss: 0.1750 - val_accuracy: 0.9375
# Epoch 196/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2586 - accuracy: 0.9097 - val_loss: 0.1839 - val_accuracy: 0.9485
# Epoch 197/200
# 97/97 [==============================] - 0s 3ms/step - loss: 0.2563 - accuracy: 0.9103 - val_loss: 0.1817 - val_accuracy: 0.9375
# Epoch 198/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2871 - accuracy: 0.9051 - val_loss: 0.1781 - val_accuracy: 0.9449
# Epoch 199/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2843 - accuracy: 0.9071 - val_loss: 0.1794 - val_accuracy: 0.9375
# Epoch 200/200
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2493 - accuracy: 0.9136 - val_loss: 0.1794 - val_accuracy: 0.9265

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4172 - accuracy: 0.8476

# %% [markdown]
# ### confusion matrix to better understand the model performance

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label))
# Out:
# 14/14 [==============================] - 0s 2ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#           Drive       0.74      0.85      0.79       100
#       Pull shot       0.85      0.92      0.88        99
#           Sweep       0.95      0.92      0.93       109
# legglance flick       0.86      0.73      0.79       125
#
#        accuracy                           0.85       433
#       macro avg       0.85      0.85      0.85       433
#    weighted avg       0.85      0.85      0.85       433
